# %% [markdown]
# #  Python II Individual Assignment
# ### Juan Francisco Balbi, GMBD 2022

# %% [markdown]
# ## 1) Import basic set of libraries for data loading/EDA

# %%
# import libraries to be used

import pandas as pd
import numpy as np
import math
import warnings
import missingno as msno
import datetime
np.random.seed(777)

# %%
# to allow multiple cells dislay

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 2) Import files to be used &  display instructions and column key

# %%
# set path & variables with file names to be imported

path = ""
instructions_name = "instructions.csv"
key_name = "Data Dictionary - Modeling Task.csv"
dataset_name = "AUTO_LOANS_DATA.csv"

# %%
# import files and create pandas dataframes

instructions = pd.read_csv(path + instructions_name,delimiter=";")
column_key = pd.read_csv(path + key_name ,delimiter=";")
data = pd.read_csv(path + dataset_name,delimiter=";")

# %%
# display instructions & column key

pd.set_option("display.max_colwidth", None ) # to display full text
instructions 
column_key
# Out:
#                                                                          INSTRUCTIONS:
# 0                        1)PERFORM DATA CLEANING (FOR EACH COLUMN: INDICATE IF DROPING
# 1                      OR KEEPING AND WHY,  FOR THE ONES KEEPING PERFORM SOME CLEANING
# 2                      OF THE MISSING VALUES OR JUSTIFY WHEN THAT IS NOT NECESSARY),
# 3                                         2)DATA PREPARATION (FOR EACH COLUMN PERFORM
# 4                       A TRANSFORMATION- FOR EXAMPLE: TIME CALCULATION LIKE AGE, DAYS
# 5                        AS CUSTOMERS,  DAYS TO DUE DATE, LABEL ENCODING, IMPUTATION,
# 6                                 STANDARD SCALLING, DUMMY CREATION OR REPLACEMENT OF
# 7                     CATEGORY VALUE BY ITS PROBABILITY OF DEFAULT DEPENDING, JUSTIFY
# 8                        TRANSFORMATION DEPENDING OF THE VARIABLE TYPE, OR EXPLAIN WHY
# 9                        TRANSFORMATION IS NOT NECESSARY) ALWAYS HAVING IN MIND THAT:
# 10                       THE OBJECTIVE IS TO PERFORM A LOGISTIC REGRESSION MODEL USING
# 11                       BUCKET BINNED (BUCKET 0 AND ALL OTHER BUCKET CATEGORIES AS 1)
# 12                    AS OUR TARGET AND THEN TRAIN A LOGISTIC REGRESSION MODEL TO USE
# 13  AS A BASELINE.  NO NEED TO IMPROVE THE MODEL, FOCUS ON DOING A GOOD DATA CLEANING.
#                Column name  \
# 0           Reporting date
# 1           Account Number
# 2              Customer ID
# 3             Program Name
# 4           Loan Open Date
# 5      Expected Close Date
# 6   Original Booked amount
# 7             Outstanding
# 8                   Bucket
# 9                      Sex
# 10      Customer Open Date
# 11              Birth date
# 12              Profession
# 13                Car Type
#
#                                                                         Description
# 0                                                         Last working day in month
# 1                                                        Loan Identification Number
# 2                                 Customer Identification Number in Credit Agricole
# 3                                           Name of program under car loans product
# 4                                                          Date of opening the loan
# 5                        The date at which the loan should be closed (end of tenor)
# 6                                               Loan Amount that the customer takes
# 7          Remaining amount of the loan that is not paid yet at this reporting date
# 8                             Number of unpaid installements at this reporting date
# 9                                          Customer's gender as per the national ID
# 10  Date of opening the relation with the customer (Can be before opening the loan)
# 11                                     Customer's birth date as per the national ID
# 12                                                            Customer's profession
# 13                                                                        Car Brand

# %% [markdown]
# ## 3) Initial EDA & scope transformations

# %%
# Get familiar with/analyze data for potential transformations and present report

print("\nPRELIMINARY EDA REPORT:\n\n")

# Basic data information
print("\n Shape: ",  data.shape) # shape of dataframe

data.head(3) # First 3 lines

data.info() # dataframe info (columns, non nulls, data types)

print("\n\n missing values:\n")
data.isnull().sum()  # missing values count

print("\n uniques:"), data.nunique() # unique value count per column
# Out:
# PRELIMINARY EDA REPORT:
#
#
#
#  Shape:  (900860, 14)
#   REPORTING_DATE  ACCOUNT_NUMBER  CUSTOMER_ID  \
# 0     2016-01-31               1            1
# 1     2016-01-31               2            2
# 2     2016-01-31               3            3
#
#                              PROGRAM_NAME LOAN_OPEN_DATE EXPECTED_CLOSE_DATE  \
# 0  Auto Loans 50% Down Payment - Employed     2015-11-25          2020-11-03
# 1                Pick Up and Small Trucks     2015-12-08          2017-12-03
# 2  Auto Loans 40% Down Payment - Employed     2016-01-12          2021-01-03
#
#   ORIGINAL_BOOKED_AMOUNT OUTSTANDING  BUCKET SEX CUSTOMER_OPEN_DATE  \
# 0                  91000     88223,4       0   M         2015-10-27
# 1                  35000    33714,82       0   M         2015-11-29
# 2                  52500       52500       0   F         2015-12-28
#
#    BIRTH_DATE PROFESSION   CAR_TYPE
# 0  1986-03-24   EMPLOYEE        KIA
# 1  1985-08-18   EMPLOYEE      CARRY
# 2  1985-07-02  HOUSEWIFE  CHEVROLET
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900860 entries, 0 to 900859
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   REPORTING_DATE          900860 non-null  object
#  1   ACCOUNT_NUMBER          900860 non-null  int64
#  2   CUSTOMER_ID             900860 non-null  int64
#  3   PROGRAM_NAME            900860 non-null  object
#  4   LOAN_OPEN_DATE          900860 non-null  object
#  5   EXPECTED_CLOSE_DATE     900860 non-null  object
#  6   ORIGINAL_BOOKED_AMOUNT  900860 non-null  object
#  7   OUTSTANDING             900860 non-null  object
#  8   BUCKET                  900860 non-null  int64
#  9   SEX                     896332 non-null  object
#  10  CUSTOMER_OPEN_DATE      900860 non-null  object
#  11  BIRTH_DATE              896327 non-null  object
#  12  PROFESSION              895302 non-null  object
#  13  CAR_TYPE                889342 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 96.2+ MB
#
#
#  missing values:
# REPORTING_DATE                0
# ACCOUNT_NUMBER                0
# CUSTOMER_ID                   0
# PROGRAM_NAME                  0
# LOAN_OPEN_DATE                0
# EXPECTED_CLOSE_DATE           0
# ORIGINAL_BOOKED_AMOUNT        0
# OUTSTANDING                   0
# BUCKET                        0
# SEX                        4528
# CUSTOMER_OPEN_DATE            0
# BIRTH_DATE                 4533
# PROFESSION                 5558
# CAR_TYPE                  11518
# dtype: int64
#  uniques:
# (None,
#  REPORTING_DATE                44
#  ACCOUNT_NUMBER             39597
#  CUSTOMER_ID                38396
#  PROGRAM_NAME                  24
#  LOAN_OPEN_DATE              2097
#  EXPECTED_CLOSE_DATE          277
#  ORIGINAL_BOOKED_AMOUNT      3486
#  OUTSTANDING               823476
#  BUCKET                         8
#  SEX                            2
#  CUSTOMER_OPEN_DATE          3094
#  BIRTH_DATE                 12966
#  PROFESSION                    51
#  CAR_TYPE                      60
#  dtype: int64)

# %%
# actions from initial EDA

print("\nInitial transformation decision based on initial EDA:\n\n-reduce dataset from loan to account level based on instructions scope and account unique values\n")
print("-unique accounts: ", data["ACCOUNT_NUMBER"].nunique()) # unique account count
print("\n-Conclusion: Reduce dataframe to account level by keeping only last loan")
# Out:
# Initial transformation decision based on initial EDA:
#
# -reduce dataset from loan to account level based on instructions scope and account unique values
#
# -unique accounts:  39597
#
# -Conclusion: Reduce dataframe to account level by keeping only last loan

# %% [markdown]
# ### 3.1 Reduce dataset from loan to account level by keeping only last loan per account

# %%
# Drop duplicates and keep only last opened loan per account 

print("\n old shape: ",  data.shape) # Confirm original dataframe shape
data_account_level = data.sort_values(by="LOAN_OPEN_DATE").drop_duplicates(subset=["ACCOUNT_NUMBER"], keep="last") # drop duplicates
print("\n new shape: ",  data_account_level.shape) # Confirm dataframe reduction
# Out:
#  old shape:  (900860, 14)
#
#  new shape:  (39597, 14)

# %% [markdown]
# ### 3.2  Preliminary EDA on account level dataset

# %%
# run preliminary eda again and print report

print("\n\nPRELIMINARY EDA REPORT ON ACCOUNT LEVEL DATASET WITH ONLY LAST LOAN PER ACCOUNT:\n\n")

# Basic data information
print("\n\n Shape: \n",data_account_level.shape) # shape of dataframe
data_account_level.info()

# Missing values
print("\n\n missing values:\n")
data_account_level.isnull().sum()  # missing values count

# Uniques and Target distribution
print("\n uniques:"), data_account_level.nunique() # unique value count per column 
print("\nBUCKET uniques = \n" , data["BUCKET"].nunique()) # confirm transformation
print("\nTarget distribution; \n", data_account_level["BUCKET"].value_counts())
# Out:
# PRELIMINARY EDA REPORT ON ACCOUNT LEVEL DATASET WITH ONLY LAST LOAN PER ACCOUNT:
#
#
#
#
#  Shape:
#  (39597, 14)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39597 entries, 5702 to 888334
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   REPORTING_DATE          39597 non-null  object
#  1   ACCOUNT_NUMBER          39597 non-null  int64
#  2   CUSTOMER_ID             39597 non-null  int64
#  3   PROGRAM_NAME            39597 non-null  object
#  4   LOAN_OPEN_DATE          39597 non-null  object
#  5   EXPECTED_CLOSE_DATE     39597 non-null  object
#  6   ORIGINAL_BOOKED_AMOUNT  39597 non-null  object
#  7   OUTSTANDING             39597 non-null  object
#  8   BUCKET                  39597 non-null  int64
#  9   SEX                     39320 non-null  object
#  10  CUSTOMER_OPEN_DATE      39597 non-null  object
#  11  BIRTH_DATE              39319 non-null  object
#  12  PROFESSION              39281 non-null  object
#  13  CAR_TYPE                37295 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 4.5+ MB
#
#
#  missing values:
# REPORTING_DATE               0
# ACCOUNT_NUMBER               0
# CUSTOMER_ID                  0
# PROGRAM_NAME                 0
# LOAN_OPEN_DATE               0
# EXPECTED_CLOSE_DATE          0
# ORIGINAL_BOOKED_AMOUNT       0
# OUTSTANDING                  0
# BUCKET                       0
# SEX                        277
# CUSTOMER_OPEN_DATE           0
# BIRTH_DATE                 278
# PROFESSION                 316
# CAR_TYPE                  2302
# dtype: int64
#  uniques:
# (None,
#  REPORTING_DATE               44
#  ACCOUNT_NUMBER            39597
#  CUSTOMER_ID               38396
#  PROGRAM_NAME                 24
#  LOAN_OPEN_DATE             2097
#  EXPECTED_CLOSE_DATE         277
#  ORIGINAL_BOOKED_AMOUNT     3486
#  OUTSTANDING               36571
#  BUCKET                        8
#  SEX                           2
#  CUSTOMER_OPEN_DATE         3094
#  BIRTH_DATE                12966
#  PROFESSION                   51
#  CAR_TYPE                     60
#  dtype: int64)
# BUCKET uniques =
#  8
#
# Target distribution;
#  0    32666
# 1     4253
# 2     1486
# 3      533
# 4      252
# 5      171
# 7      150
# 6       86
# Name: BUCKET, dtype: int64

# %% [markdown]
# ## 4) DATA CLEANING AND TRANSFORMATIONS

# %% [markdown]
# ### 4.1 Group columns for transformations/cleaning and present transformation/cleaning plan

# %%
# group columns for transformation/ cleansing

drop_unecessary = ["REPORTING_DATE",  "CUSTOMER_ID"]  # not needed identifiers columns
date_columns = [ "LOAN_OPEN_DATE", "EXPECTED_CLOSE_DATE", "CUSTOMER_OPEN_DATE", "BIRTH_DATE"] # change to datetime to days
to_numeric = ["ORIGINAL_BOOKED_AMOUNT", "OUTSTANDING"] # columns that need change to numeric
incomplete_features = ["SEX", "BIRTH_DATE", "PROFESSION", "CAR_TYPE"] # columns with nulls

# %%
# Transformations/Cleanning PLAN

print("\nPLAN FOR TRANSFORMATIONS/CLEANING NEEDED ACCORDING TO PRELIMINARY EDA:\n\n-bin bucket column and set it as target, \n-remove  (" f"{drop_unecessary=})" , "\n-change object numbers to numeric (" f"{to_numeric=})","\n-date columns in string to datetime to deltas (", f"{date_columns=})", "\n-Analyze missingness to decide splitiing dataset, \n-encode categoricals, \n-impute missing values (", f"{incomplete_features=})")
# Out:
# PLAN FOR TRANSFORMATIONS/CLEANING NEEDED ACCORDING TO PRELIMINARY EDA:
#
# -bin bucket column and set it as target,
# -remove  (drop_unecessary=['REPORTING_DATE', 'CUSTOMER_ID'])
# -change object numbers to numeric (to_numeric=['ORIGINAL_BOOKED_AMOUNT', 'OUTSTANDING'])
# -date columns in string to datetime to deltas ( date_columns=['LOAN_OPEN_DATE', 'EXPECTED_CLOSE_DATE', 'CUSTOMER_OPEN_DATE', 'BIRTH_DATE'])
# -Analyze missingness to decide splitiing dataset,
# -encode categoricals,
# -impute missing values ( incomplete_features=['SEX', 'BIRTH_DATE', 'PROFESSION', 'CAR_TYPE'])

# %% [markdown]
# ### 4.2 bin bucket column

# %%
# SET TARGET as per instructions and confirm

category= ["0","1"] # categories
data_account_level['BUCKET_BINNED']= pd.cut(x=data['BUCKET'], bins=[-1,0,7],labels=category).astype(int) # Set bins
data_account_level.drop('BUCKET', inplace=True, axis=1) # drop old "bucket" column
data_account_level.head(1) # confirm transformation
print("BUCKET_BINNED uniques = " , data_account_level["BUCKET_BINNED"].nunique()) # confirm transformation
# Out:
#      REPORTING_DATE  ACCOUNT_NUMBER  CUSTOMER_ID  \
# 5702     2016-01-31            5703         5644
#
#                                 PROGRAM_NAME LOAN_OPEN_DATE  \
# 5702  Auto Loans 40% Down Payment - Employed     2009-09-16
#
#      EXPECTED_CLOSE_DATE ORIGINAL_BOOKED_AMOUNT OUTSTANDING SEX  \
# 5702          2016-02-03                  96000     4220,82   F
#
#      CUSTOMER_OPEN_DATE  BIRTH_DATE     PROFESSION CAR_TYPE  BUCKET_BINNED
# 5702         2009-07-20  1969-01-25  Company Owner      NaN              1
# BUCKET_BINNED uniques =  2

# %% [markdown]
# ### 4.3 remove unecessary columns

# %%
# drop unecessary from drop_unecessary list and confirm drop

drop_unecessary # Display unecessary
data_account_level.drop(drop_unecessary, axis=1, inplace=True) # drop inplace
data_account_level.columns # confirm drop
# Out:
# ['REPORTING_DATE', 'CUSTOMER_ID']
# Index(['ACCOUNT_NUMBER', 'PROGRAM_NAME', 'LOAN_OPEN_DATE',
#        'EXPECTED_CLOSE_DATE', 'ORIGINAL_BOOKED_AMOUNT', 'OUTSTANDING', 'SEX',
#        'CUSTOMER_OPEN_DATE', 'BIRTH_DATE', 'PROFESSION', 'CAR_TYPE',
#        'BUCKET_BINNED'],
#       dtype='object')

# %% [markdown]
# ### 4.4 transform string number features to numeric

# %%
# Transform to_numeric columns (ORIGINAL_BOOKED_AMOUNT and OUTSTANDING) to floats

pd.options.display.float_format = '{:,.0f}'.format #set float format

data_account_level[to_numeric] = data[to_numeric].apply(lambda x: x.str.replace(',','.')) # replace "," with "." 
data_account_level[to_numeric] = data_account_level[to_numeric].apply(lambda x: x.astype('float')) # transform strings to floats
data_account_level[to_numeric] = data_account_level[to_numeric].apply(np.int64)# transform floats to ints
data_account_level[to_numeric].head(3) # Confirm transformation in dataframe
data_account_level[to_numeric].dtypes  # Confirm data types
# Out:
#         ORIGINAL_BOOKED_AMOUNT  OUTSTANDING
# 5702                     96000         4220
# 151957                   63600            0
# 32457                    41400            0
# ORIGINAL_BOOKED_AMOUNT    int64
# OUTSTANDING               int64
# dtype: object

# %% [markdown]
# ### 4.4) tarnsform date columns from string to datetime to DAYS /AGE

# %%
# print columns to be transformed, perform transformation to datetime and confirm

print("date_columns = ", date_columns)
data_account_level[date_columns] = data_account_level[date_columns].apply(pd.to_datetime) # convert date columns to datetime format for further transformations
data_account_level[date_columns].dtypes # confirm transformation to datetime
# Out:
# date_columns =  ['LOAN_OPEN_DATE', 'EXPECTED_CLOSE_DATE', 'CUSTOMER_OPEN_DATE', 'BIRTH_DATE']
# LOAN_OPEN_DATE         datetime64[ns]
# EXPECTED_CLOSE_DATE    datetime64[ns]
# CUSTOMER_OPEN_DATE     datetime64[ns]
# BIRTH_DATE             datetime64[ns]
# dtype: object

# %%
# Transform datetime columns into days/years (to/from) equivalents

data_account_level['DAYS_SINCE_LOAN_OPEN'] =  (pd.Timestamp('today') - data_account_level['LOAN_OPEN_DATE']).dt.days # get days since loan open

data_account_level['DAYS_TO_DUE_DATE'] =  (  pd.Timestamp('today') - data_account_level['EXPECTED_CLOSE_DATE'] ).dt.days # get days to loan close
data_account_level['DAYS_AS_CUSTOMER'] = (pd.Timestamp('today') - data_account_level['CUSTOMER_OPEN_DATE']).dt.days # get days as customer

today = datetime.date.today()  # set today for use in age lambda

data_account_level["AGE"] = data_account_level["BIRTH_DATE"].map(lambda x: today.year - x.year - ((today.month, today.day) < (x.month, x.day))) # get age
data_account_level["AGE"] = data_account_level["AGE"].astype("Int64")

data_account_level.drop(date_columns, axis=1, inplace=True) # drop old date_columns

data_account_level.head(1) # confirm date transformations/drops
data_account_level.info()  # confirm date transformations/drops
# Out:
#       ACCOUNT_NUMBER                            PROGRAM_NAME  \
# 5702            5703  Auto Loans 40% Down Payment - Employed
#
#       ORIGINAL_BOOKED_AMOUNT  OUTSTANDING SEX     PROFESSION CAR_TYPE  \
# 5702                   96000         4220   F  Company Owner      NaN
#
#       BUCKET_BINNED  DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 5702              1                  4376              2045              4434
#
#       AGE
# 5702   52
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39597 entries, 5702 to 888334
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ACCOUNT_NUMBER          39597 non-null  int64
#  1   PROGRAM_NAME            39597 non-null  object
#  2   ORIGINAL_BOOKED_AMOUNT  39597 non-null  int64
#  3   OUTSTANDING             39597 non-null  int64
#  4   SEX                     39320 non-null  object
#  5   PROFESSION              39281 non-null  object
#  6   CAR_TYPE                37295 non-null  object
#  7   BUCKET_BINNED           39597 non-null  int64
#  8   DAYS_SINCE_LOAN_OPEN    39597 non-null  int64
#  9   DAYS_TO_DUE_DATE        39597 non-null  int64
#  10  DAYS_AS_CUSTOMER        39597 non-null  int64
#  11  AGE                     39319 non-null  Int64
# dtypes: Int64(1), int64(7), object(4)
# memory usage: 4.0+ MB

# %% [markdown]
# ## 5) Analyze missingness in account level data for MNAR/MAR patterns/dataframe split

# %%
# Missing values 
print("missing values:\n")
data_account_level.isnull().sum()

# Visualize missing values as a matrix/heatmap to identify Missing at random/not at random
msno.matrix(data_account_level)
msno.heatmap(data_account_level)
# Out:
# missing values:
# ACCOUNT_NUMBER               0
# PROGRAM_NAME                 0
# ORIGINAL_BOOKED_AMOUNT       0
# OUTSTANDING                  0
# SEX                        277
# PROFESSION                 316
# CAR_TYPE                  2302
# BUCKET_BINNED                0
# DAYS_SINCE_LOAN_OPEN         0
# DAYS_TO_DUE_DATE             0
# DAYS_AS_CUSTOMER             0
# AGE                        278
# dtype: int64
# <AxesSubplot:>
# <AxesSubplot:>

# %%
for i in (data_account_level.columns):
    if data_account_level[i].isnull().sum() >= 1:
        print(data_account_level.columns[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-ff3b753b888f> in <module>
#       1 for i in (data_account_level.columns):
#       2     if data_account_level[i].isnull().sum() >= 1:
# ----> 3         print(data_account_level.columns[i])
#       4
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#ANALIZE MISSINGNESS based on PROGRAM NAME

data_account_level[["SEX", "AGE", "PROFESSION", "CAR_TYPE"]].isnull().groupby(data_account_level['PROGRAM_NAME']).sum()
# Out:
#                                                                 SEX  AGE  \
# PROGRAM_NAME
# Auto Loans 20% Down Payment - Employed                            0    0
# Auto Loans 20% Down Payment - Self Employed                       0    0
# Auto Loans 30% Down Payment - Employed                            0    0
# Auto Loans 30% Down Payment - Self Employed                       0    0
# Auto Loans 30% Down Payment Used Cars - Employed                  0    0
# Auto Loans 30% Down Payment Used Cars - Self Employed             0    0
# Auto Loans 40% Down Payment - Employed                            0    0
# Auto Loans 40% Down Payment - Self Employed                       0    0
# Auto Loans 50% Down Payment - Employed                            0    0
# Auto Loans 50% Down Payment - Self Employed                       0    0
# Auto Loans 50% Down Payment No Car Prohibition - Employed         0    0
# Auto Loans 50% Down Payment No Car Prohibition - Self Employed    0    0
# Auto Loans 50% Down Payment Used Cars - Employed                  0    0
# Auto Loans 50% Down Payment Used Cars - Self Employed             0    0
# Auto Loans Corporate Guarantee                                  277  278
# Auto Loans Doctors - Employed                                     0    0
# Auto Loans Doctors - Self Employed                                0    0
# Auto Loans Fully Secured                                          0    0
# Auto Loans Payroll Clients                                        0    0
# Auto Loans Run Off - Employed                                     0    0
# Auto Loans Run Off - Self Employed                                0    0
# Auto Loans Secured against CD                                     0    0
# Auto Loans Special Deals                                          0    0
# Pick Up and Small Trucks                                          0    0
#
#                                                                 PROFESSION  \
# PROGRAM_NAME
# Auto Loans 20% Down Payment - Employed                                   1
# Auto Loans 20% Down Payment - Self Employed                              0
# Auto Loans 30% Down Payment - Employed                                   5
# Auto Loans 30% Down Payment - Self Employed                              1
# Auto Loans 30% Down Payment Used Cars - Employed                         0
# Auto Loans 30% Down Payment Used Cars - Self Employed                    0
# Auto Loans 40% Down Payment - Employed                                   3
# Auto Loans 40% Down Payment - Self Employed                              7
# Auto Loans 50% Down Payment - Employed                                   5
# Auto Loans 50% Down Payment - Self Employed                             15
# Auto Loans 50% Down Payment No Car Prohibition - Employed                0
# Auto Loans 50% Down Payment No Car Prohibition - Self Employed           1
# Auto Loans 50% Down Payment Used Cars - Employed                         0
# Auto Loans 50% Down Payment Used Cars - Self Employed                    0
# Auto Loans Corporate Guarantee                                         278
# Auto Loans Doctors - Employed                                            0
# Auto Loans Doctors - Self Employed                                       0
# Auto Loans Fully Secured                                                 0
# Auto Loans Payroll Clients                                               0
# Auto Loans Run Off - Employed                                            0
# Auto Loans Run Off - Self Employed                                       0
# Auto Loans Secured against CD                                            0
# Auto Loans Special Deals                                                 0
# Pick Up and Small Trucks                                                 0
#
#                                                                 CAR_TYPE
# PROGRAM_NAME
# Auto Loans 20% Down Payment - Employed                                25
# Auto Loans 20% Down Payment - Self Employed                            9
# Auto Loans 30% Down Payment - Employed                               120
# Auto Loans 30% Down Payment - Self Employed                           14
# Auto Loans 30% Down Payment Used Cars - Employed                       0
# Auto Loans 30% Down Payment Used Cars - Self Employed                  0
# Auto Loans 40% Down Payment - Employed                               283
# Auto Loans 40% Down Payment - Self Employed                          191
# Auto Loans 50% Down Payment - Employed                               600
# Auto Loans 50% Down Payment - Self Employed                          876
# Auto Loans 50% Down Payment No Car Prohibition - Employed              0
# Auto Loans 50% Down Payment No Car Prohibition - Self Employed         0
# Auto Loans 50% Down Payment Used Cars - Employed                       0
# Auto Loans 50% Down Payment Used Cars - Self Employed                  0
# Auto Loans Corporate Guarantee                                        42
# Auto Loans Doctors - Employed                                          8
# Auto Loans Doctors - Self Employed                                     1
# Auto Loans Fully Secured                                              10
# Auto Loans Payroll Clients                                             7
# Auto Loans Run Off - Employed                                          0
# Auto Loans Run Off - Self Employed                                     0
# Auto Loans Secured against CD                                          8
# Auto Loans Special Deals                                              29
# Pick Up and Small Trucks                                              79

# %%
# missingness report and recomendations

print("Missingness report and recomendations: \n\n-MNAR:AGE,PROFESSION and SEX are highly correlated amongst themselves and with Auto Loans Corporate Guarantee group in Program name and seems to be MNAR.\n-MAR: Car_Type seems to be MAR and should be imputed on both datasets.\n\n-RECOMENDATIONS: \n1)SPLIT the dataset on PROGRAM_NAME= Auto loans Corporate Guarantee as data_corporate and drop AGE,SEX and PROFESSION \n2)Reat of data to be included as data_individual \n3)Impute MAR on both data_corporate and data_individual")
# Out:
# Missingness report and recomendations:
#
# -MNAR:AGE,PROFESSION and SEX are highly correlated amongst themselves and with Auto Loans Corporate Guarantee group in Program name and seems to be MNAR.
# -MAR: Car_Type seems to be MAR and should be imputed on both datasets.
#
# -RECOMENDATIONS:
# 1)SPLIT the dataset on PROGRAM_NAME= Auto loans Corporate Guarantee as data_corporate and drop AGE,SEX and PROFESSION
# 2)Reat of data to be included as data_individual
# 3)Impute MAR on both data_corporate and data_individual

# %% [markdown]
# ## 6) Split dataset into corporate/individual segments based on MNAR

# %%
# Split data into data_corporate and data_individual to be processed separately

data_corporate = data_account_level.groupby(data.PROGRAM_NAME).get_group("Auto Loans Corporate Guarantee") # set subgroup as data_corporate 
data_corporate.drop(["AGE","SEX","PROFESSION","PROGRAM_NAME"], axis=1, inplace=True) # drop inplace MNAR features
data_individual = data_account_level.drop(data_corporate.index) # Drop splited subgroup from original data and set it as data_individual

# Confirm data_corporate/data_individual split
print("Split succesful? : ",len(data_account_level)==len(data_corporate) + len(data_individual), "\nRUN scaling/imputations/model on each dataset individually:\n-data_corporate\n-data_individual")
# Out:
# Split succesful? :  True
# RUN scaling/imputations/model on each dataset individually:
# -data_corporate
# -data_individual
# /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## 7) Corporate dataset analysis/transformations/modelling/baseline

# %% [markdown]
# ### 7.1) Corporate: Preliminary EDA

# %%
# Corporate EDA and Action Plan

print("\nshape: ", data_corporate.shape)
data_corporate.head(3)
data_corporate.info()
print("\nNulls; \n", data_corporate.isnull().sum())
print("\nTarget distribution; \n", data_corporate["BUCKET_BINNED"].value_counts())
print("\n\nActions:  \n-Impute missing values \n-Remove outliers \n-Scale data \n-Perform final eda before modelling \n-Train Model \n-Get Accuracy metric as baseline")
# Out:
# shape:  (278, 8)
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING CAR_TYPE  \
# 2531             2532                   64000         2844      NaN
# 1097             1098                   66000         6015  HYUNDAI
# 66706           16833                   66000         3042  HYUNDAI
#
#        BUCKET_BINNED  DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER
# 2531               0                  3807              1983              7607
# 1097               0                  3773              1947              4398
# 66706              1                  3773              1947              4398
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278 entries, 2531 to 888652
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ACCOUNT_NUMBER          278 non-null    int64
#  1   ORIGINAL_BOOKED_AMOUNT  278 non-null    int64
#  2   OUTSTANDING             278 non-null    int64
#  3   CAR_TYPE                236 non-null    object
#  4   BUCKET_BINNED           278 non-null    int64
#  5   DAYS_SINCE_LOAN_OPEN    278 non-null    int64
#  6   DAYS_TO_DUE_DATE        278 non-null    int64
#  7   DAYS_AS_CUSTOMER        278 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 19.5+ KB
#
# Nulls;
#  ACCOUNT_NUMBER             0
# ORIGINAL_BOOKED_AMOUNT     0
# OUTSTANDING                0
# CAR_TYPE                  42
# BUCKET_BINNED              0
# DAYS_SINCE_LOAN_OPEN       0
# DAYS_TO_DUE_DATE           0
# DAYS_AS_CUSTOMER           0
# dtype: int64
#
# Target distribution;
#  0    235
# 1     43
# Name: BUCKET_BINNED, dtype: int64
#
#
# Actions:
# -Impute missing values
# -Remove outliers
# -Scale data
# -Perform final eda before modelling
# -Train Model
# -Get Accuracy metric as baseline

# %% [markdown]
# ### 7.2) Corporate: Impute MAR values using most frequent value
# ##### (attempted to implement KNN imputation but could not make it work)

# %%
# identify missing values

data_corporate.isnull().sum()
# Out:
# ACCOUNT_NUMBER             0
# ORIGINAL_BOOKED_AMOUNT     0
# OUTSTANDING                0
# CAR_TYPE                  42
# BUCKET_BINNED              0
# DAYS_SINCE_LOAN_OPEN       0
# DAYS_TO_DUE_DATE           0
# DAYS_AS_CUSTOMER           0
# dtype: int64

# %%
# Function to replace NAN values with most frequent value/mode

def impute_nan_most_frequent_category(DataFrame,ColName):
    # .mode()[0] - gives first category name
     most_frequent_category=DataFrame[ColName].mode()[0]
    
    # replace nan values with most occured category
     DataFrame[ColName + "_Imputed"] = DataFrame[ColName]
     DataFrame[ColName + "_Imputed"].fillna(most_frequent_category,inplace=True)

# %%
# Impute by calling function to impute most occured category

impute_nan_most_frequent_category(data_corporate,"CAR_TYPE")
    
# Drop actual columns
data_corporate.drop("CAR_TYPE", axis=1, inplace=True)

data_corporate.head(1) # confirm imputation
data_corporate.isnull().sum() # confirm imputation
# Out:
# /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531            2532                   64000         2844              0
#
#       DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                  3807              1983              7607
#
#      CAR_TYPE_Imputed
# 2531          HYUNDAI
# ACCOUNT_NUMBER            0
# ORIGINAL_BOOKED_AMOUNT    0
# OUTSTANDING               0
# BUCKET_BINNED             0
# DAYS_SINCE_LOAN_OPEN      0
# DAYS_TO_DUE_DATE          0
# DAYS_AS_CUSTOMER          0
# CAR_TYPE_Imputed          0
# dtype: int64

# %% [markdown]
# ### 7.3) Corporate: Outlier detection/removal and Scaling

# %%
# create numerical/categorical lists and print them out

data_c_numerical = list(data_corporate.select_dtypes(include=['number'])) 
data_c_numerical = [e for e in data_c_numerical if e not in ("ACCOUNT_NUMBER", "BUCKET_BINNED")]

data_c_categorical = list(data_corporate.select_dtypes(exclude=['number']))

print("Numerical:", data_c_numerical)
print("Categorical:", data_c_categorical)
# Out:
# Numerical: ['ORIGINAL_BOOKED_AMOUNT', 'OUTSTANDING', 'DAYS_SINCE_LOAN_OPEN', 'DAYS_TO_DUE_DATE', 'DAYS_AS_CUSTOMER']
# Categorical: ['CAR_TYPE_Imputed']

# %%
#detect and remove outliers in numerical features

Q1 = data_corporate[data_c_numerical].quantile(0.25)
Q3 = data_corporate[data_c_numerical].quantile(0.75)
IQR = Q3 - Q1

data_corporate = data_corporate[~((data_corporate[data_c_numerical] < (Q1 - 1.5 * IQR)) |(data_corporate[data_c_numerical] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Scale numerical features

from sklearn.preprocessing import StandardScaler # import scaler

scaler = StandardScaler() # set scaler

data_corporate[data_c_numerical] = scaler.fit_transform(data_corporate[data_c_numerical]) # run scalar

data_corporate.head(3) # confirm scaling
# Out:
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531             2532                      -1           -1              0
# 9015             9016                       0           -1              0
# 21186           21187                       0           -1              0
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                      2                 2                 0
# 9015                      2                 2                 0
# 21186                     2                 2                 0
#
#       CAR_TYPE_Imputed
# 2531           HYUNDAI
# 9015           HYUNDAI
# 21186          HYUNDAI

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(["paris", "paris", "tokyo", "amsterdam"])
le.transform(["tokyo", "tokyo", "paris"])

# %% [markdown]
# ## Experiments

# %%
features_with_missing =

# %%
conda update scikit-learn
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/juanbalbi/opt/anaconda3
#   package name: scikit-learn
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+git://github.com/andirs/impyte.git
# Out:
# Collecting git+git://github.com/andirs/impyte.git
#   Cloning git://github.com/andirs/impyte.git to /private/var/folders/h1/qbvw89td0s36p5czw924rwf40000gn/T/pip-req-build-we5ui05f
#   Running command git clone -q git://github.com/andirs/impyte.git /private/var/folders/h1/qbvw89td0s36p5czw924rwf40000gn/T/pip-req-build-we5ui05f
#   Resolved git://github.com/andirs/impyte.git to commit e838352b3378fab9b6a40261a38acd198f554f8a
# Requirement already satisfied: scikit-learn in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from impyte==0.1.0) (1.0.dev0)
# Requirement already satisfied: pandas in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from impyte==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from impyte==0.1.0) (1.20.3)
# Requirement already satisfied: scipy in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from impyte==0.1.0) (1.6.2)
# Requirement already satisfied: pathlib in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from impyte==0.1.0) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from pandas->impyte==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from pandas->impyte==0.1.0) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->impyte==0.1.0) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->impyte==0.1.0) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->impyte==0.1.0) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
Python 3.6
sklearn 0.19
pandas 0.21
scipy 0.19
pathlib 1.0.1

# %%
conda list
# Out:
# # packages in environment at /Users/juanbalbi/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.07                  py38_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _r-mutex                  1.0.0               anacondar_1
# alabaster                 0.7.12             pyhd3eb1b0_0
# altgraph                  0.17                     pypi_0    pypi
# anaconda                  custom                   py38_1
# anaconda-client           1.8.0            py38hecd8cb5_0
# anaconda-navigator        2.0.4                    py38_0
# anaconda-project          0.10.1             pyhd3eb1b0_0
# anyio                     2.2.0            py38hecd8cb5_1
# appdirs                   1.4.4                      py_0
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.2           py38hecd8cb5_1001
# appscript                 1.1.2            py38h9ed2024_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38h9ed2024_1
# arrow                     0.13.1                   py38_0
# asn1crypto                1.4.0                      py_0
# astroid                   2.6.5            py38hecd8cb5_0
# astropy                   4.2.1            py38h9ed2024_1
# async_generator           1.10               pyhd3eb1b0_0
# atomicwrites              1.4.0                      py_0
# attrs                     21.2.0             pyhd3eb1b0_0
# autopep8                  1.5.3                      py_0
# babel                     2.9.1              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.0                pyhd3eb1b0_2
# backports-entry-points-selectable 1.1.0                    pypi_0    pypi
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.shutil_get_terminal_size 1.0.0              pyhd3eb1b0_3
# backports.tempfile        1.0                pyhd3eb1b0_1
# backports.weakref         1.0.post1                  py_1
# beautifulsoup4            4.9.3              pyha847dfd_0
# binaryornot               0.4.4              pyhd3eb1b0_1
# bitarray                  2.1.0            py38h9ed2024_1
# bkcharts                  0.2                      py38_0
# black                     19.10b0                    py_0
# blas                      1.0                         mkl
# bleach                    3.3.1              pyhd3eb1b0_0
# blosc                     1.21.0               h2842e9f_0
# bokeh                     2.3.3            py38hecd8cb5_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38hf1fa96c_1
# brotlipy                  0.7.0           py38h9ed2024_1003
# bzip2                     1.0.8                h1de35cc_0
# c-ares                    1.17.1               h9ed2024_0
# ca-certificates           2021.7.5             hecd8cb5_1
# certifi                   2021.5.30        py38hecd8cb5_0
# cffi                      1.14.6           py38h2125817_0
# chardet                   4.0.0           py38hecd8cb5_1003
# click                     8.0.1              pyhd3eb1b0_0
# cloudpickle               1.6.0                      py_0
# clyent                    1.2.2                    py38_1
# cmdstanpy                 0.9.5                    pypi_0    pypi
# colorama                  0.4.4              pyhd3eb1b0_0
# conda                     4.10.3           py38hecd8cb5_0
# conda-build               3.21.4           py38hecd8cb5_0
# conda-content-trust       0.1.1              pyhd3eb1b0_0
# conda-env                 2.6.0                         1
# conda-pack                0.6.0              pyhd3eb1b0_0
# conda-package-handling    1.7.3            py38h9ed2024_1
# conda-repo-cli            1.0.4              pyhd3eb1b0_0
# conda-token               0.3.0              pyhd3eb1b0_0
# conda-verify              3.4.2                      py_1
# confuse                   1.4.0                    pypi_0    pypi
# contextlib2               0.6.0.post1                py_0
# convertdate               2.3.0                    pypi_0    pypi
# cookiecutter              1.7.2              pyhd3eb1b0_0
# cryptography              3.4.7            py38h2fd3fbb_0
# curl                      7.71.1               h7bc2e8c_2
# cycler                    0.10.0                   py38_0
# cython                    0.29.24          py38h23ab428_0
# cytoolz                   0.11.0           py38haf1e3a3_0
# dask                      2021.7.0           pyhd3eb1b0_0
# dask-core                 2021.7.0           pyhd3eb1b0_0
# dataset                   0.17.1                   pypi_0    pypi
# dbus                      1.13.18              h18a8e69_0
# decorator                 5.0.9              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# diff-match-patch          20200713                   py_0
# distlib                   0.3.2                    pypi_0    pypi
# distributed               2021.7.0         py38hecd8cb5_0
# distro                    1.5.0                    pypi_0    pypi
# docutils                  0.17.1           py38hecd8cb5_1
# entrypoints               0.3                      py38_0
# ephem                     3.7.7.1                  pypi_0    pypi
# et_xmlfile                1.1.0            py38hecd8cb5_0
# expat                     2.4.1                h23ab428_2
# fastcache                 1.1.0            py38h1de35cc_0
# filelock                  3.0.12             pyhd3eb1b0_1
# flake8                    3.8.3                      py_0
# flask                     1.1.2              pyhd3eb1b0_0
# flask-sqlalchemy          2.5.1                    pypi_0    pypi
# freetype                  2.10.4               ha233b18_0
# fsspec                    2021.7.0           pyhd3eb1b0_0
# future                    0.18.2                   py38_1
# get_terminal_size         1.0.0                h7520d66_0
# gettext                   0.21.0               h7535e17_0
# gevent                    21.1.2           py38h9ed2024_1
# gitdb                     4.0.7                    pypi_0    pypi
# gitpython                 3.1.18                   pypi_0    pypi
# glib                      2.69.0               hdf23fa2_0
# glob2                     0.7                pyhd3eb1b0_0
# gmp                       6.2.1                h23ab428_2
# gmpy2                     2.0.8            py38h6ef4df4_3
# googletrans               3.0.0                    pypi_0    pypi
# greenlet                  1.1.0            py38h23ab428_0
# h11                       0.9.0                    pypi_0    pypi
# h2                        3.2.0                    pypi_0    pypi
# h5py                      2.10.0           py38h3134771_0
# hdf5                      1.10.4               hfa1e0ec_0
# heapdict                  1.0.1                      py_0
# holidays                  0.10.4                   pypi_0    pypi
# hpack                     3.0.0                    pypi_0    pypi
# hstspreload               2020.12.22               pypi_0    pypi
# html5lib                  1.1                        py_0
# htmlmin                   0.1.12                   pypi_0    pypi
# httpcore                  0.9.1                    pypi_0    pypi
# httpx                     0.13.3                   pypi_0    pypi
# hyperframe                5.2.0                    pypi_0    pypi
# icu                       58.2                 h0a44026_3
# idna                      2.10               pyhd3eb1b0_0
# imagehash                 4.2.0                    pypi_0    pypi
# imageio                   2.9.0              pyhd3eb1b0_0
# imagesize                 1.2.0              pyhd3eb1b0_0
# importlib-metadata        3.10.0           py38hecd8cb5_0
# importlib_metadata        3.10.0               hd3eb1b0_0
# impyte                    0.1.0                    pypi_0    pypi
# inflection                0.5.1            py38hecd8cb5_0
# iniconfig                 1.1.1              pyhd3eb1b0_0
# intel-openmp              2021.3.0          hecd8cb5_3375
# intervaltree              3.1.0                      py_0
# ipykernel                 5.3.4            py38h5ca1d4c_0
# ipython                   7.22.0           py38h01d92e1_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# ipywidgets                7.6.3              pyhd3eb1b0_1
# isort                     5.9.2              pyhd3eb1b0_0
# itsdangerous              2.0.1              pyhd3eb1b0_0
# jbig                      2.1                  h4d881f8_0
# jdcal                     1.4.1                      py_0
# jedi                      0.17.2           py38hecd8cb5_1
# jinja2                    2.11.3             pyhd3eb1b0_0
# jinja2-time               0.2.0              pyhd3eb1b0_2
# joblib                    1.0.1              pyhd3eb1b0_0
# jpeg                      9b                   he5867d9_2
# json5                     0.9.6              pyhd3eb1b0_0
# jsonschema                3.2.0                      py_2
# jupyter                   1.0.0                    py38_7
# jupyter-packaging         0.7.12             pyhd3eb1b0_0
# jupyter-server-mathjax    0.2.3                    pypi_0    pypi
# jupyter_client            6.1.12             pyhd3eb1b0_0
# jupyter_console           6.4.0              pyhd3eb1b0_0
# jupyter_core              4.7.1            py38hecd8cb5_0
# jupyter_server            1.4.1            py38hecd8cb5_0
# jupyterlab                3.1.9                    pypi_0    pypi
# jupyterlab-git            0.32.2                   pypi_0    pypi
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.6.1              pyhd3eb1b0_0
# jupyterlab_widgets        1.0.0              pyhd3eb1b0_1
# keyring                   23.0.1           py38hecd8cb5_0
# kiwisolver                1.3.1            py38h23ab428_0
# korean-lunar-calendar     0.2.1                    pypi_0    pypi
# krb5                      1.19.2               hcd88c3b_0
# lazy-object-proxy         1.6.0            py38h9ed2024_0
# lcms2                     2.12                 hf1fd2bf_0
# libarchive                3.4.2                haa3ed63_0
# libcurl                   7.71.1               hb8e4fae_2
# libcxx                    10.0.0                        1
# libedit                   3.1.20210216         h9ed2024_1
# libev                     4.33                 haf1e3a3_0
# libffi                    3.3                  hb1e8313_2
# libgcc                    4.8.5               hdbeacc1_10
# libgfortran               3.0.1                h93005f0_2
# libiconv                  1.16                 h1de35cc_0
# liblief                   0.10.1               h0a44026_0
# libllvm10                 10.0.1               h76017ad_5
# libllvm9                  9.0.1                h21ff451_1
# libpng                    1.6.37               ha441bb4_0
# libsodium                 1.0.18               h1de35cc_0
# libspatialindex           1.9.3                h23ab428_0
# libssh2                   1.9.0                ha12b0ac_1
# libtiff                   4.2.0                h87d7836_0
# libuv                     1.40.0               haf1e3a3_0
# libwebp-base              1.2.0                h9ed2024_0
# libxml2                   2.9.12               hcdb78fc_0
# libxslt                   1.1.34               h83b36ba_0
# llvm-openmp               10.0.0               h28b9765_0
# llvmlite                  0.36.0           py38he4411ff_4
# locket                    0.2.1            py38hecd8cb5_1
# lunarcalendar             0.0.9                    pypi_0    pypi
# lxml                      4.6.3            py38h26b266a_0
# lz4-c                     1.9.3                h23ab428_0
# lzo                       2.10                 haf1e3a3_2
# macholib                  1.14                     pypi_0    pypi
# markupsafe                1.1.1            py38h1de35cc_1
# matplotlib                3.3.4            py38hecd8cb5_0
# matplotlib-base           3.3.4            py38h8b3ea08_0
# mccabe                    0.6.1                    py38_1
# missingno                 0.4.2                    pypi_0    pypi
# mistune                   0.8.4           py38h1de35cc_1001
# mkl                       2021.3.0           hecd8cb5_517
# mkl-service               2.4.0            py38h9ed2024_0
# mkl_fft                   1.3.0            py38h4a7008c_2
# mkl_random                1.2.2            py38hb2f4e1b_0
# mock                      4.0.3              pyhd3eb1b0_0
# more-itertools            8.8.0              pyhd3eb1b0_0
# mpc                       1.1.0                h6ef4df4_1
# mpfr                      4.0.2                h9066e36_1
# mpmath                    1.2.1            py38hecd8cb5_0
# msgpack-python            1.0.2            py38hf7b0b51_1
# multimethod               1.4                      pypi_0    pypi
# multipledispatch          0.6.0                    py38_0
# mypy_extensions           0.4.3                    py38_0
# navigator-updater         0.2.1                    py38_0
# nbclassic                 0.2.6              pyhd3eb1b0_0
# nbclient                  0.5.3              pyhd3eb1b0_0
# nbconvert                 6.1.0            py38hecd8cb5_0
# nbdime                    3.1.0                    pypi_0    pypi
# nbformat                  5.1.3              pyhd3eb1b0_0
# nbsphinx                  0.8.6                    pypi_0    pypi
# ncurses                   6.2                  h0a44026_1
# nest-asyncio              1.5.1              pyhd3eb1b0_0
# networkx                  2.6.1              pyhd3eb1b0_0
# nltk                      3.6.2              pyhd3eb1b0_0
# nose                      1.3.7           pyhd3eb1b0_1006
# notebook                  6.4.0            py38hecd8cb5_0
# numba                     0.53.1           py38hb2f4e1b_0
# numexpr                   2.7.3            py38h5873af2_1
# numpy                     1.20.3           py38h4b4dc7a_0
# numpy-base                1.20.3           py38he0bd621_0
# numpydoc                  1.1.0              pyhd3eb1b0_1
# olefile                   0.46                       py_0
# openjpeg                  2.3.0                hb95cd4c_1
# openpyxl                  3.0.7              pyhd3eb1b0_0
# openssl                   1.1.1k               h9ed2024_0
# packaging                 21.0               pyhd3eb1b0_0
# pandas                    1.3.0            py38h23ab428_0
# pandas-bokeh              0.5.2                    pypi_0    pypi
# pandas-datareader         0.9.0                    pypi_0    pypi
# pandas-profiling          3.0.0                    pypi_0    pypi
# pandoc                    2.12                 hecd8cb5_0
# pandocfilters             1.4.3            py38hecd8cb5_1
# parso                     0.7.0                      py_0
# partd                     1.2.0              pyhd3eb1b0_0
# path                      16.0.0           py38hecd8cb5_0
# path.py                   12.5.0                        0
# pathlib                   1.0.1                    pypi_0    pypi
# pathlib2                  2.3.6            py38hecd8cb5_2
# pathspec                  0.7.0                      py_0
# pathtools                 0.1.2                      py_1
# patsy                     0.5.1                    py38_0
# pcre                      8.45                 h23ab428_0
# pep8                      1.7.1                    py38_0
# pexpect                   4.8.0              pyhd3eb1b0_3
# phik                      0.12.0                   pypi_0    pypi
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    8.3.1            py38ha4cf6ea_0
# pip                       21.2.4                   pypi_0    pypi
# pkginfo                   1.7.1            py38hecd8cb5_0
# platformdirs              2.1.0                    pypi_0    pypi
# plotly                    4.13.0                   pypi_0    pypi
# pluggy                    0.13.1           py38hecd8cb5_0
# ply                       3.11                     py38_0
# poyo                      0.5.0              pyhd3eb1b0_0
# prometheus_client         0.11.0             pyhd3eb1b0_0
# prompt-toolkit            3.0.17             pyh06a4308_0
# prompt_toolkit            3.0.17               hd3eb1b0_0
# psutil                    5.8.0            py38h9ed2024_1
# ptyprocess                0.7.0              pyhd3eb1b0_2
# py                        1.10.0             pyhd3eb1b0_0
# py-lief                   0.10.1           py38haf313ee_0
# pycodestyle               2.6.0              pyhd3eb1b0_0
# pycosat                   0.6.3            py38h1de35cc_1
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.6         py38hddc9c9b_0
# pydantic                  1.8.2                    pypi_0    pypi
# pydocstyle                6.1.1              pyhd3eb1b0_0
# pyerfa                    2.0.0            py38h9ed2024_0
# pyflakes                  2.2.0              pyhd3eb1b0_0
# pygments                  2.9.0              pyhd3eb1b0_0
# pyinstaller               4.1                      pypi_0    pypi
# pyinstaller-hooks-contrib 2020.10                  pypi_0    pypi
# pylint                    2.9.5            py38hecd8cb5_1
# pyls-black                0.4.6                hd3eb1b0_0
# pyls-spyder               0.3.2              pyhd3eb1b0_0
# pymeeus                   0.3.7                    pypi_0    pypi
# pyodbc                    4.0.31           py38h23ab428_0
# pyopenssl                 20.0.1             pyhd3eb1b0_1
# pyparsing                 2.4.7              pyhd3eb1b0_0
# pyqt                      5.9.2            py38h655552a_2
# pyreadstat                1.1.2                    pypi_0    pypi
# pyrsistent                0.17.3           py38haf1e3a3_0
# pysocks                   1.7.1                    py38_1
# pystan                    2.19.1.1                 pypi_0    pypi
# pytables                  3.6.1            py38h4727e94_0
# pytest                    6.2.4            py38hecd8cb5_2
# python                    3.8.10               h88f2d9e_7
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-jsonrpc-server     0.4.0                      py_0
# python-language-server    0.36.2             pyhd3eb1b0_0
# python-libarchive-c       2.9                pyhd3eb1b0_1
# python-slugify            5.0.2              pyhd3eb1b0_0
# python.app                3                py38h9ed2024_0
# pytz                      2021.1             pyhd3eb1b0_0
# pywavelets                1.1.1            py38haf1e3a3_2
# pyyaml                    5.4.1            py38h9ed2024_1
# pyzmq                     20.0.0           py38h23ab428_1
# qdarkstyle                3.0.2              pyhd3eb1b0_0
# qstylizer                 0.1.10             pyhd3eb1b0_0
# qt                        5.9.7                h468cd18_1
# qtawesome                 1.0.2              pyhd3eb1b0_0
# qtconsole                 5.1.0              pyhd3eb1b0_0
# qtpy                      1.9.0                      py_0
# r                         3.2.2                         0
# r-assertthat              0.1                   r3.2.2_2a    r
# r-base                    3.2.2                         0
# r-bh                      1.58.0_1              r3.2.2_0a    r
# r-boot                    1.3_17                r3.2.2_0a    r
# r-class                   7.3_14                r3.2.2_0a    r
# r-cluster                 2.0.3                 r3.2.2_0a    r
# r-codetools               0.2_14                r3.2.2_0a    r
# r-dbi                     0.3.1                 r3.2.2_3a    r
# r-dplyr                   0.4.3                 r3.2.2_0a    r
# r-foreign                 0.8_66                r3.2.2_0a    r
# r-kernsmooth              2.23_15               r3.2.2_0a    r
# r-lattice                 0.20_33               r3.2.2_0a    r
# r-lazyeval                0.1.10                r3.2.2_3a    r
# r-magrittr                1.5                   r3.2.2_2a    r
# r-mass                    7.3_45                r3.2.2_0a    r
# r-matrix                  1.2_2                 r3.2.2_0a    r
# r-mgcv                    1.8_9                 r3.2.2_0a    r
# r-nlme                    3.1_122               r3.2.2_0a    r
# r-nnet                    7.3_11                r3.2.2_0a    r
# r-r6                      2.1.1                 r3.2.2_0a    r
# r-rcpp                    0.12.2                r3.2.2_0a    r
# r-recommended             3.2.2                  r3.2.2_0    r
# r-rpart                   4.1_10                r3.2.2_0a    r
# r-spatial                 7.3_11                r3.2.2_0a    r
# r-survival                2.38_3                r3.2.2_0a    r
# readline                  8.1                  h9ed2024_0
# regex                     2021.7.6         py38h9ed2024_0
# requests                  2.25.1             pyhd3eb1b0_0
# retrying                  1.3.3                    pypi_0    pypi
# rfc3986                   1.4.0                    pypi_0    pypi
# ripgrep                   12.1.1                        0
# rope                      0.19.0             pyhd3eb1b0_0
# rtree                     0.9.7            py38hecd8cb5_1
# ruamel_yaml               0.15.100         py38h9ed2024_0
# scikit-image              0.16.2           py38h6c726b0_0
# scikit-learn              1.0.dev0                 pypi_0    pypi
# scipy                     1.6.2            py38hd5f7400_1
# seaborn                   0.11.1             pyhd3eb1b0_0
# send2trash                1.5.0              pyhd3eb1b0_1
# setuptools                57.4.0                   pypi_0    pypi
# setuptools-git            1.2                      pypi_0    pypi
# simplegeneric             0.8.1                    py38_2
# singledispatch            3.6.2           pyhd3eb1b0_1001
# sip                       4.19.8           py38h0a44026_0
# six                       1.16.0             pyhd3eb1b0_0
# sklearn-pandas            2.2.0                    pypi_0    pypi
# skrebate                  0.62                     pypi_0    pypi
# smmap                     4.0.0                    pypi_0    pypi
# snappy                    1.1.8                hb1e8313_0
# sniffio                   1.2.0            py38hecd8cb5_1
# snowballstemmer           2.1.0              pyhd3eb1b0_0
# sortedcollections         2.1.0              pyhd3eb1b0_0
# sortedcontainers          2.4.0              pyhd3eb1b0_0
# soupsieve                 2.2.1              pyhd3eb1b0_0
# sphinx                    4.0.2              pyhd3eb1b0_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2              pyhd3eb1b0_0
# sphinxcontrib-devhelp     1.0.2              pyhd3eb1b0_0
# sphinxcontrib-htmlhelp    2.0.0              pyhd3eb1b0_0
# sphinxcontrib-jsmath      1.0.1              pyhd3eb1b0_0
# sphinxcontrib-qthelp      1.0.3              pyhd3eb1b0_0
# sphinxcontrib-serializinghtml 1.1.5              pyhd3eb1b0_0
# sphinxcontrib-websupport  1.2.4                      py_0
# spyder                    5.0.5            py38hecd8cb5_2
# spyder-kernels            2.0.5            py38hecd8cb5_0
# sqlalchemy                1.4.22           py38h9ed2024_0
# sqlite                    3.36.0               hce871da_0
# statsmodels               0.12.2           py38h9ed2024_0
# sympy                     1.8              py38hecd8cb5_0
# tabula-py                 2.2.0                    pypi_0    pypi
# tangled-up-in-unicode     0.1.0                    pypi_0    pypi
# tbb                       2020.3               h879752b_0
# tblib                     1.7.0                      py_0
# terminado                 0.9.4            py38hecd8cb5_0
# testpath                  0.5.0              pyhd3eb1b0_0
# text-unidecode            1.3                        py_0
# textdistance              4.2.1              pyhd3eb1b0_0
# threadpoolctl             2.2.0              pyhb85f177_0
# three-merge               0.1.1              pyhd3eb1b0_0
# tinycss                   0.4             pyhd3eb1b0_1002
# tk                        8.6.10               hb0a8c7a_0
# toml                      0.10.2             pyhd3eb1b0_0
# toolz                     0.11.1             pyhd3eb1b0_0
# tornado                   6.1              py38h9ed2024_0
# tqdm                      4.61.2             pyhd3eb1b0_1
# traitlets                 5.0.5              pyhd3eb1b0_0
# typed-ast                 1.4.3            py38h9ed2024_1
# typing_extensions         3.10.0.0           pyh06a4308_0
# ujson                     4.0.2            py38h23ab428_0
# unicodecsv                0.14.1                   py38_0
# unidecode                 1.2.0              pyhd3eb1b0_0
# unixodbc                  2.3.9                haf1e3a3_0
# urllib3                   1.26.6             pyhd3eb1b0_1
# virtualenv                20.6.0                   pypi_0    pypi
# visions                   0.7.1                    pypi_0    pypi
# watchdog                  1.0.2            py38h9ed2024_1
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# werkzeug                  1.0.1              pyhd3eb1b0_0
# wheel                     0.37.0                   pypi_0    pypi
# whichcraft                0.6.1              pyhd3eb1b0_0
# widgetsnbextension        3.5.1                    py38_0
# wrapt                     1.12.1           py38haf1e3a3_1
# wurlitzer                 2.1.1            py38hecd8cb5_0
# xlrd                      2.0.1              pyhd3eb1b0_0
# xlsxwriter                1.4.4              pyhd3eb1b0_0
# xlwings                   0.24.3           py38hecd8cb5_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0
# xz                        5.2.5                h1de35cc_0
# yaml                      0.2.5                haf1e3a3_0
# yapf                      0.31.0             pyhd3eb1b0_0
# zeromq                    4.3.4                h23ab428_0
# zict                      2.0.0              pyhd3eb1b0_0
# zipp                      3.5.0              pyhd3eb1b0_0
# zlib                      1.2.11               h1de35cc_3
# zope                      1.0                      py38_1
# zope.event                4.5.0                    py38_0
# zope.interface            5.4.0            py38h9ed2024_0
# zstd                      1.4.9                h322a384_0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/juanbalbi/opt/anaconda3
#   package name: scikit-learn
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.0.dev0.

# %%
from impyte import impyte
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-5504453ad18a> in <module>
# ----> 1 from impyte import impyte
#
# ~/opt/anaconda3/lib/python3.8/site-packages/impyte/impyte.py in <module>
#      10 from datetime import date
#      11 from pathlib import Path
# ---> 12 from sklearn.externals import joblib
#      13 from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, \
#      14      GradientBoostingRegressor, GradientBoostingClassifier
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (/Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/sklearn/externals/__init__.py)

# %%
from impyte import impyte

df = pd.read_csv("missing_values.csv")
imp = impyte.Impyter(df)

# show nan-patterns of data in one data frame
imp.pattern() # shows nan-patterns

# imputation of all single-nans using random forest
imp.impute(estimator='rf')

# imputation of all nan-patterns
imp.impute(estimator='rf', multi_nans=True)

# use f1 and r2 thresholds
imp.impute(estimator='rf', threshold={"r2": .7, "f1_macro": .7})

# %%
data_corporate_e = data_corporate
data_corporate_e.head()
# Out:
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531             2532                   64000         2844              0
# 1097             1098                   66000         6015              0
# 66706           16833                   66000         3042              1
# 57610           14712                  200000         9205              1
# 56479           20325                  118500         5426              1
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                   3807              1983              7607
# 1097                   3773              1947              4398
# 66706                  3773              1947              4398
# 57610                  3773              1947              4398
# 56479                  3754              1947              4398
#
#       CAR_TYPE_Imputed
# 2531           HYUNDAI
# 1097           HYUNDAI
# 66706          HYUNDAI
# 57610         MERCEDES
# 56479              KIA

# %%
# grouping by frequency
fq = data_corporate_e.groupby('CAR_TYPE_Imputed').size()/len(data_corporate_e)   
# mapping values to dataframe
data_corporate_e.loc[:, "{}_freq_encode".format('CAR_TYPE_Imputed')] = data_corporate_e['CAR_TYPE_Imputed'].map(fq)  
# drop original column.
#df = df.drop(['CAR_TYPE_Imputed'], axis = 1) 
fq.plot.bar(stacked = True)  
data_corporate_e.head(10)
# Out:
# /Users/juanbalbi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# <AxesSubplot:xlabel='CAR_TYPE_Imputed'>
#         ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531              2532                   64000         2844              0
# 1097              1098                   66000         6015              0
# 66706            16833                   66000         3042              1
# 57610            14712                  200000         9205              1
# 56479            20325                  118500         5426              1
# 14698            14699                  100000         9260              1
# 170934            1104                  200000            0              0
# 47626            12121                   99200        13284              0
# 1368              1369                  134400            0              0
# 9015              9016                  150000            0              0
#
#         DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                    3807              1983              7607
# 1097                    3773              1947              4398
# 66706                   3773              1947              4398
# 57610                   3773              1947              4398
# 56479                   3754              1947              4398
# 14698                   3753              1947              4398
# 170934                  3683              1855              4398
# 47626                   3633              1824              4697
# 1368                    3611              1794              4697
# 9015                    3495              2043              7607
#
#        CAR_TYPE_Imputed  CAR_TYPE_Imputed_freq_encode
# 2531            HYUNDAI                             0
# 1097            HYUNDAI                             0
# 66706           HYUNDAI                             0
# 57610          MERCEDES                             0
# 56479               KIA                             0
# 14698               KIA                             0
# 170934              BMW                             0
# 47626           HYUNDAI                             0
# 1368            HYUNDAI                             0
# 9015            HYUNDAI                             0

# %%
from sklearn import preprocessing

LabelEncoder = preprocessing.LabelEncoder()

class MultiColumnLabelEncoder:

    def __init__(self, columns=None):
        self.columns = columns # array of column names to encode


    def fit(self, X, y=None):
        self.encoders = {}
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            self.encoders[col] = LabelEncoder().fit(X[col])
        return self


    def transform(self, X):
        output = X.copy()
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            output[col] = self.encoders[col].transform(X[col])
        return output


    def fit_transform(self, X, y=None):
        return self.fit(X,y).transform(X)


    def inverse_transform(self, X):
        output = X.copy()
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            output[col] = self.encoders[col].inverse_transform(X[col])
        return output

# %%
multi = MultiColumnLabelEncoder(columns=['CAR_TYPE_Imputed'])
data_corporate_e = data_corporate
X = multi.fit_transform(data_corporate_e)
print(X)
inv = multi.inverse_transform(X)
print(inv)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-3032a47ec96b> in <module>
#       1 multi = MultiColumnLabelEncoder(columns=['CAR_TYPE_Imputed'])
#       2 data_corporate_e = data_corporate
# ----> 3 X = multi.fit_transform(data_corporate_e)
#       4 print(X)
#       5 inv = multi.inverse_transform(X)
#
# <ipython-input-128-88237454e23b> in fit_transform(self, X, y)
#      26
#      27     def fit_transform(self, X, y=None):
# ---> 28         return self.fit(X,y).transform(X)
#      29
#      30
#
# <ipython-input-128-88237454e23b> in fit(self, X, y)
#      13         columns = X.columns if self.columns is None else self.columns
#      14         for col in columns:
# ---> 15             self.encoders[col] = LabelEncoder().fit(X[col])
#      16         return self
#      17
#
# TypeError: 'LabelEncoder' object is not callable

# %%
data_corporate_2['CAR_TYPE_Imputed'].nunique()
# Out:
# 28

# %%
data_corporate_2['CAR_TYPE_Imputed'].value_counts().sum()
# Out:
# 278

# %%
data_corporate_2['CAR_TYPE_Imputed'].value_counts()/data_corporate_2['CAR_TYPE_Imputed'].value_counts().sum()
# Out:
# HYUNDAI      0
# NISSAN       0
# KIA          0
# CHEVROLET    0
# RENAULT      0
# TOYOTA       0
# MITSUBISHI   0
# MERCEDES     0
# BMW          0
# CHERY        0
# VOLKSWAGEN   0
# FIAT         0
# FORD         0
# SKODA        0
# Brilliance   0
# Citroen      0
# BAIC         0
# Jack         0
# LADA         0
# SEAT         0
# BYD          0
# MAZDA        0
# OPEL         0
# MINI         0
# DAIHATSU     0
# SUBARU       0
# Peugeot      0
# Ssang Yong   0
# Name: CAR_TYPE_Imputed, dtype: float64

# %%
encoding = data_corporate.groupby('CAR_TYPE_Imputed').count()
#encoding = encoding/len(data_corporate)   ##calculates frequency
data_corporate_2= data_corporate
#data_corporate_2['enc'] = data_corporate_2.CAR_TYPE_Imputed.map('encoding')

# %%
encoding
# Out:
#                   ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  \
# CAR_TYPE_Imputed
# BAIC                           0                       0            0
# BMW                            0                       0            0
# BYD                            0                       0            0
# Brilliance                     0                       0            0
# CHERY                          0                       0            0
# CHEVROLET                      0                       0            0
# Citroen                        0                       0            0
# DAIHATSU                       0                       0            0
# FIAT                           0                       0            0
# FORD                           0                       0            0
# HYUNDAI                        0                       0            0
# Jack                           0                       0            0
# KIA                            0                       0            0
# LADA                           0                       0            0
# MAZDA                          0                       0            0
# MERCEDES                       0                       0            0
# MINI                           0                       0            0
# MITSUBISHI                     0                       0            0
# NISSAN                         0                       0            0
# OPEL                           0                       0            0
# Peugeot                        0                       0            0
# RENAULT                        0                       0            0
# SEAT                           0                       0            0
# SKODA                          0                       0            0
# SUBARU                         0                       0            0
# Ssang Yong                     0                       0            0
# TOYOTA                         0                       0            0
# VOLKSWAGEN                     0                       0            0
#
#                   BUCKET_BINNED  DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  \
# CAR_TYPE_Imputed
# BAIC                          0                     0                 0
# BMW                           0                     0                 0
# BYD                           0                     0                 0
# Brilliance                    0                     0                 0
# CHERY                         0                     0                 0
# CHEVROLET                     0                     0                 0
# Citroen                       0                     0                 0
# DAIHATSU                      0                     0                 0
# FIAT                          0                     0                 0
# FORD                          0                     0                 0
# HYUNDAI                       0                     0                 0
# Jack                          0                     0                 0
# KIA                           0                     0                 0
# LADA                          0                     0                 0
# MAZDA                         0                     0                 0
# MERCEDES                      0                     0                 0
# MINI                          0                     0                 0
# MITSUBISHI                    0                     0                 0
# NISSAN                        0                     0                 0
# OPEL                          0                     0                 0
# Peugeot                       0                     0                 0
# RENAULT                       0                     0                 0
# SEAT                          0                     0                 0
# SKODA                         0                     0                 0
# SUBARU                        0                     0                 0
# Ssang Yong                    0                     0                 0
# TOYOTA                        0                     0                 0
# VOLKSWAGEN                    0                     0                 0
#
#                   DAYS_AS_CUSTOMER
# CAR_TYPE_Imputed
# BAIC                             0
# BMW                              0
# BYD                              0
# Brilliance                       0
# CHERY                            0
# CHEVROLET                        0
# Citroen                          0
# DAIHATSU                         0
# FIAT                             0
# FORD                             0
# HYUNDAI                          0
# Jack                             0
# KIA                              0
# LADA                             0
# MAZDA                            0
# MERCEDES                         0
# MINI                             0
# MITSUBISHI                       0
# NISSAN                           0
# OPEL                             0
# Peugeot                          0
# RENAULT                          0
# SEAT                             0
# SKODA                            0
# SUBARU                           0
# Ssang Yong                       0
# TOYOTA                           0
# VOLKSWAGEN                       0

# %%
from sklearn import preprocessing
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'Country'. 
data_corporate_1 = data_corporate
data_corporate_1['CAR_TYPE_Imputed']= label_encoder.fit_transform(data_corporate_1['CAR_TYPE_Imputed']) 
data_corporate_1.head()
# Out:
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531             2532                      -1           -1              0
# 9015             9016                       0           -1              0
# 21186           21187                       0           -1              0
# 20706           20707                       0           -1              0
# 11215           11216                      -1           -1              0
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                      2                 2                 0
# 9015                      2                 2                 0
# 21186                     2                 2                 0
# 20706                     2                 2                 0
# 11215                     1                 2                 0
#
#        CAR_TYPE_Imputed
# 2531                  8
# 9015                  8
# 21186                 8
# 20706                 8
# 11215                 8

# %%
data_corporate_1['CAR_TYPE_Imputed']
# Out:
# 2531       8
# 9015       8
# 21186      8
# 20706      8
# 11215      8
#           ..
# 876316     9
# 824464     8
# 779471     3
# 843047     6
# 861826    11
# Name: CAR_TYPE_Imputed, Length: 199, dtype: int64

# %%
data_corporate_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 2531 to 861826
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ACCOUNT_NUMBER          199 non-null    int64
#  1   ORIGINAL_BOOKED_AMOUNT  199 non-null    float64
#  2   OUTSTANDING             199 non-null    float64
#  3   BUCKET_BINNED           199 non-null    int64
#  4   DAYS_SINCE_LOAN_OPEN    199 non-null    float64
#  5   DAYS_TO_DUE_DATE        199 non-null    float64
#  6   DAYS_AS_CUSTOMER        199 non-null    float64
#  7   CAR_TYPE_Imputed        199 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 14.0 KB

# %%
list(label_encoder.inverse_transform(["CAR_TYPE_imputed"]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-e3bdf623d929> in <module>
# ----> 1 list(label_encoder.inverse_transform(["CAR_TYPE_imputed"]))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_label.py in inverse_transform(self, y)
#     161         diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     162         if len(diff):
# --> 163             raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     164         y = np.asarray(y)
#     165         return self.classes_[y]
#
# ValueError: y contains previously unseen labels: ['CAR_TYPE_imputed']

# %% [markdown]
# ### 7.4) Corporate: dummy encode  categoricals for logistic regression
# ##### (attempted to implement forward and backwards feature selection after dummy encoding but could not make it work)

# %%
# data_corporate shape after outlier removal

data_corporate.shape
# Out:
# (199, 8)

# %%
# Dummy encode categorical columns for KNN imputation and logistic regression

dc_cat_variables = data_corporate[data_c_categorical]  # set categorical columns to be encoded

dc_cat_dummies = pd.get_dummies(dc_cat_variables) # dummy encode categorical columns
dc_cat_dummies = dc_cat_dummies.astype("Int64")

dc_cat_dummies.head(3)  # confirm encoding
# Out:
#        CAR_TYPE_Imputed_BAIC  CAR_TYPE_Imputed_BMW  \
# 2531                       0                     0
# 9015                       0                     0
# 21186                      0                     0
#
#        CAR_TYPE_Imputed_Brilliance  CAR_TYPE_Imputed_CHERY  \
# 2531                             0                       0
# 9015                             0                       0
# 21186                            0                       0
#
#        CAR_TYPE_Imputed_CHEVROLET  CAR_TYPE_Imputed_Citroen  \
# 2531                            0                         0
# 9015                            0                         0
# 21186                           0                         0
#
#        CAR_TYPE_Imputed_FIAT  CAR_TYPE_Imputed_FORD  CAR_TYPE_Imputed_HYUNDAI  \
# 2531                       0                      0                         1
# 9015                       0                      0                         1
# 21186                      0                      0                         1
#
#        CAR_TYPE_Imputed_Jack  ...  CAR_TYPE_Imputed_MERCEDES  \
# 2531                       0  ...                          0
# 9015                       0  ...                          0
# 21186                      0  ...                          0
#
#        CAR_TYPE_Imputed_MITSUBISHI  CAR_TYPE_Imputed_NISSAN  \
# 2531                             0                        0
# 9015                             0                        0
# 21186                            0                        0
#
#        CAR_TYPE_Imputed_OPEL  CAR_TYPE_Imputed_Peugeot  \
# 2531                       0                         0
# 9015                       0                         0
# 21186                      0                         0
#
#        CAR_TYPE_Imputed_RENAULT  CAR_TYPE_Imputed_SKODA  \
# 2531                          0                       0
# 9015                          0                       0
# 21186                         0                       0
#
#        CAR_TYPE_Imputed_SUBARU  CAR_TYPE_Imputed_TOYOTA  \
# 2531                         0                        0
# 9015                         0                        0
# 21186                        0                        0
#
#        CAR_TYPE_Imputed_VOLKSWAGEN
# 2531                             0
# 9015                             0
# 21186                            0
#
# [3 rows x 22 columns]

# %%
# Drop dummy encoded original column and concat new dummy columns

data_corporate = pd.concat([ data_corporate, dc_cat_dummies], axis=1) # Concat the two dataframes together
data_corporate.drop("CAR_TYPE_Imputed", axis=1, inplace=True)

data_corporate.head(3)  # confirm drop/concat
# Out:
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531             2532                      -1           -1              0
# 9015             9016                       0           -1              0
# 21186           21187                       0           -1              0
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                      2                 2                 0
# 9015                      2                 2                 0
# 21186                     2                 2                 0
#
#        CAR_TYPE_Imputed_BAIC  CAR_TYPE_Imputed_BMW  \
# 2531                       0                     0
# 9015                       0                     0
# 21186                      0                     0
#
#        CAR_TYPE_Imputed_Brilliance  ...  CAR_TYPE_Imputed_MERCEDES  \
# 2531                             0  ...                          0
# 9015                             0  ...                          0
# 21186                            0  ...                          0
#
#        CAR_TYPE_Imputed_MITSUBISHI  CAR_TYPE_Imputed_NISSAN  \
# 2531                             0                        0
# 9015                             0                        0
# 21186                            0                        0
#
#        CAR_TYPE_Imputed_OPEL  CAR_TYPE_Imputed_Peugeot  \
# 2531                       0                         0
# 9015                       0                         0
# 21186                      0                         0
#
#        CAR_TYPE_Imputed_RENAULT  CAR_TYPE_Imputed_SKODA  \
# 2531                          0                       0
# 9015                          0                       0
# 21186                         0                       0
#
#        CAR_TYPE_Imputed_SUBARU  CAR_TYPE_Imputed_TOYOTA  \
# 2531                         0                        0
# 9015                         0                        0
# 21186                        0                        0
#
#        CAR_TYPE_Imputed_VOLKSWAGEN
# 2531                             0
# 9015                             0
# 21186                            0
#
# [3 rows x 29 columns]

# %% [markdown]
# ### 7.5) Corporate: EDA

# %%
# EDA

data_corporate.shape
data_corporate.head()
data_corporate.info()
data_corporate.describe()
# Out:
# (199, 29)
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# 2531             2532                      -1           -1              0
# 9015             9016                       0           -1              0
# 21186           21187                       0           -1              0
# 20706           20707                       0           -1              0
# 11215           11216                      -1           -1              0
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# 2531                      2                 2                 0
# 9015                      2                 2                 0
# 21186                     2                 2                 0
# 20706                     2                 2                 0
# 11215                     1                 2                 0
#
#        CAR_TYPE_Imputed_BAIC  CAR_TYPE_Imputed_BMW  \
# 2531                       0                     0
# 9015                       0                     0
# 21186                      0                     0
# 20706                      0                     0
# 11215                      0                     0
#
#        CAR_TYPE_Imputed_Brilliance  ...  CAR_TYPE_Imputed_MERCEDES  \
# 2531                             0  ...                          0
# 9015                             0  ...                          0
# 21186                            0  ...                          0
# 20706                            0  ...                          0
# 11215                            0  ...                          0
#
#        CAR_TYPE_Imputed_MITSUBISHI  CAR_TYPE_Imputed_NISSAN  \
# 2531                             0                        0
# 9015                             0                        0
# 21186                            0                        0
# 20706                            0                        0
# 11215                            0                        0
#
#        CAR_TYPE_Imputed_OPEL  CAR_TYPE_Imputed_Peugeot  \
# 2531                       0                         0
# 9015                       0                         0
# 21186                      0                         0
# 20706                      0                         0
# 11215                      0                         0
#
#        CAR_TYPE_Imputed_RENAULT  CAR_TYPE_Imputed_SKODA  \
# 2531                          0                       0
# 9015                          0                       0
# 21186                         0                       0
# 20706                         0                       0
# 11215                         0                       0
#
#        CAR_TYPE_Imputed_SUBARU  CAR_TYPE_Imputed_TOYOTA  \
# 2531                         0                        0
# 9015                         0                        0
# 21186                        0                        0
# 20706                        0                        0
# 11215                        0                        0
#
#        CAR_TYPE_Imputed_VOLKSWAGEN
# 2531                             0
# 9015                             0
# 21186                            0
# 20706                            0
# 11215                            0
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 2531 to 861826
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ACCOUNT_NUMBER               199 non-null    int64
#  1   ORIGINAL_BOOKED_AMOUNT       199 non-null    float64
#  2   OUTSTANDING                  199 non-null    float64
#  3   BUCKET_BINNED                199 non-null    int64
#  4   DAYS_SINCE_LOAN_OPEN         199 non-null    float64
#  5   DAYS_TO_DUE_DATE             199 non-null    float64
#  6   DAYS_AS_CUSTOMER             199 non-null    float64
#  7   CAR_TYPE_Imputed_BAIC        199 non-null    Int64
#  8   CAR_TYPE_Imputed_BMW         199 non-null    Int64
#  9   CAR_TYPE_Imputed_Brilliance  199 non-null    Int64
#  10  CAR_TYPE_Imputed_CHERY       199 non-null    Int64
#  11  CAR_TYPE_Imputed_CHEVROLET   199 non-null    Int64
#  12  CAR_TYPE_Imputed_Citroen     199 non-null    Int64
#  13  CAR_TYPE_Imputed_FIAT        199 non-null    Int64
#  14  CAR_TYPE_Imputed_FORD        199 non-null    Int64
#  15  CAR_TYPE_Imputed_HYUNDAI     199 non-null    Int64
#  16  CAR_TYPE_Imputed_Jack        199 non-null    Int64
#  17  CAR_TYPE_Imputed_KIA         199 non-null    Int64
#  18  CAR_TYPE_Imputed_MAZDA       199 non-null    Int64
#  19  CAR_TYPE_Imputed_MERCEDES    199 non-null    Int64
#  20  CAR_TYPE_Imputed_MITSUBISHI  199 non-null    Int64
#  21  CAR_TYPE_Imputed_NISSAN      199 non-null    Int64
#  22  CAR_TYPE_Imputed_OPEL        199 non-null    Int64
#  23  CAR_TYPE_Imputed_Peugeot     199 non-null    Int64
#  24  CAR_TYPE_Imputed_RENAULT     199 non-null    Int64
#  25  CAR_TYPE_Imputed_SKODA       199 non-null    Int64
#  26  CAR_TYPE_Imputed_SUBARU      199 non-null    Int64
#  27  CAR_TYPE_Imputed_TOYOTA      199 non-null    Int64
#  28  CAR_TYPE_Imputed_VOLKSWAGEN  199 non-null    Int64
# dtypes: Int64(22), float64(5), int64(2)
# memory usage: 50.9 KB
#        ACCOUNT_NUMBER  ORIGINAL_BOOKED_AMOUNT  OUTSTANDING  BUCKET_BINNED  \
# count             199                     199          199            199
# mean           18,739                       0           -0              0
# std            11,736                       1            1              0
# min               302                      -2           -1              0
# 25%             8,312                      -1           -1              0
# 50%            17,508                       0           -0              0
# 75%            31,814                       1            1              0
# max            36,714                       3            2              1
#
#        DAYS_SINCE_LOAN_OPEN  DAYS_TO_DUE_DATE  DAYS_AS_CUSTOMER  \
# count                   199               199               199
# mean                     -0                -0                 0
# std                       1                 1                 0
# min                      -2                -2                 0
# 25%                      -1                -1                 0
# 50%                       0                 0                 0
# 75%                       1                 1                 0
# max                       2                 2                 0
#
#        CAR_TYPE_Imputed_BAIC  CAR_TYPE_Imputed_BMW  \
# count                    199                   199
# mean                       0                     0
# std                        0                     0
# min                        0                     0
# 25%                        0                     0
# 50%                        0                     0
# 75%                        0                     0
# max                        1                     1
#
#        CAR_TYPE_Imputed_Brilliance  ...  CAR_TYPE_Imputed_MERCEDES  \
# count                          199  ...                        199
# mean                             0  ...                          0
# std                              0  ...                          0
# min                              0  ...                          0
# 25%                              0  ...                          0
# 50%                              0  ...                          0
# 75%                              0  ...                          0
# max                              1  ...                          1
#
#        CAR_TYPE_Imputed_MITSUBISHI  CAR_TYPE_Imputed_NISSAN  \
# count                          199                      199
# mean                             0                        0
# std                              0                        0
# min                              0                        0
# 25%                              0                        0
# 50%                              0                        0
# 75%                              0                        0
# max                              1                        1
#
#        CAR_TYPE_Imputed_OPEL  CAR_TYPE_Imputed_Peugeot  \
# count                    199                       199
# mean                       0                         0
# std                        0                         0
# min                        0                         0
# 25%                        0                         0
# 50%                        0                         0
# 75%                        0                         0
# max                        1                         1
#
#        CAR_TYPE_Imputed_RENAULT  CAR_TYPE_Imputed_SKODA  \
# count                       199                     199
# mean                          0                       0
# std                           0                       0
# min                           0                       0
# 25%                           0                       0
# 50%                           0                       0
# 75%                           0                       0
# max                           1                       1
#
#        CAR_TYPE_Imputed_SUBARU  CAR_TYPE_Imputed_TOYOTA  \
# count                      199                      199
# mean                         0                        0
# std                          0                        0
# min                          0                        0
# 25%                          0                        0
# 50%                          0                        0
# 75%                          0                        0
# max                          1                        1
#
#        CAR_TYPE_Imputed_VOLKSWAGEN
# count                          199
# mean                             0
# std                              0
# min                              0
# 25%                              0
# 50%                              0
# 75%                              0
# max                              1
#
# [8 rows x 29 columns]

# %% [markdown]
# ### 7.6 ) Corporate:  Logit regression and Baseline metrics

# %%
# Import libraries needed

import pandas as pd
import numpy as np
from sklearn import metrics 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Set X and Y for split/model

Xc = data_corporate
yc = data_corporate["BUCKET_BINNED"]
Xc.drop(["ACCOUNT_NUMBER", "BUCKET_BINNED"], axis=1, inplace=True)

# %%
# Function to split/train/evaluate logistic regression model

from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, matthews_corrcoef

def evaluate_LogReg(X, y,
                    metric: str='accuracy',
                    seed: int=123,
                    printout: bool=False):
    """
    Fits a logistic regression with the training set, and evaluates it with 
    the test set, using Accuracy, F1, Recall or MCC metrics.

    Params
      X: A Pandas DataFrame with all the values to be used to fit the logit
      y: The dependent variable.
      metric: The metric to be returned
      printout: True/False indicating whether you want to print results

    """
    # Split the data 
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state= 123, )

    # Train Model
    lr_clf = LogisticRegression().fit(X_train, y_train)
    y_hat = lr_clf.predict(X_test)

    # Metrics
    accuracy = accuracy_score(y_test, y_hat)
    F1 = f1_score(y_test, y_hat)
    recall = recall_score(y_test, y_hat)
    MCC = matthews_corrcoef(y_test, y_hat)
    roc_auc = roc_auc_score(y_test, y_hat)
    Gini = 2*roc_auc-1
    
    if printout is True:
        print('Accuracy:', accuracy)
        print('F1:', F1)
        print('Recall:', recall)
        print('roc_auc:', roc_auc)
        print('Gini:', Gini)
    
    return eval(metric)

# %% [markdown]
# ### 7.7) Corporate:  Final Result/Baseline Metrics

# %%
# call evaluate_LogReg function to split/train/evaluate logistic regression model with set X,y

corporate_accuracy_lr = evaluate_LogReg(Xc, yc, printout=True)
corporate_accuracy_lr
# Out:
# Accuracy: 0.825
# F1: 0.0
# Recall: 0.0
# roc_auc: 0.5
# Gini: 0.0
# 0.825

# %% [markdown]
# ## Experiments

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, matthews_corrcoef
from sklearn.tree import DecisionTreeClassifier

def evaluate_DecisionTree(X, y,
                    metric: str='accuracy',
                    seed: int=123,
                    printout: bool=False):
    """
    Fits a decision tree with the training set, and evaluates it with 
    the test set, using Accuracy, F1, Recall or MCC metrics.

    Params
      X: A Pandas DataFrame with all the values to be used to fit the logit
      y: The dependent variable.
      metric: The metric to be returned
      printout: True/False indicating whether you want to print results

    """
    # Split the data 
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state= 123, )

    # Train Model
    dt_clf = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1).fit(X_train, y_train)
    y_hat = dt_clf.predict(X_test)

    # Metrics
    accuracy = accuracy_score(y_test, y_hat)
    F1 = f1_score(y_test, y_hat)
    recall = recall_score(y_test, y_hat)
    MCC = matthews_corrcoef(y_test, y_hat)
    roc_auc = roc_auc_score(y_test, y_hat)
    Gini = 2*roc_auc-1
    
    if printout is True:
        print('Accuracy:', accuracy)
        print('F1:', F1)
        print('Recall:', recall)
        print('roc_auc:', roc_auc)
        print('Gini:', Gini)
    
    return eval(metric)

# %%
corporate_accuracy_dt = evaluate_DecisionTree(Xc, yc, printout=True)
corporate_accuracy_dt
# Out:
# Accuracy: 0.825
# F1: 0.0
# Recall: 0.0
# roc_auc: 0.5
# Gini: 0.0
# 0.825

# %%
X= Xc
y= yc
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 123, )

# Train Model
dt_clf = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1).fit(X_train, y_train)
y_hat = dt_clf.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
fig, ax = plt.subplots(figsize=(10, 10))
tree.plot_tree(dt_clf, fontsize=10)
plt.show()
# Out:
# [Text(333.25, 489.24, 'X[2] <= 0.277\ngini = 0.274\nsamples = 159\nvalue = [133, 26]'),
#  Text(201.5, 380.52000000000004, 'X[6] <= 0.5\ngini = 0.072\nsamples = 80\nvalue = [77, 3]'),
#  Text(124.0, 271.8, 'X[23] <= 0.5\ngini = 0.051\nsamples = 77\nvalue = [75, 2]'),
#  Text(62.0, 163.08000000000004, 'X[15] <= 0.5\ngini = 0.027\nsamples = 74\nvalue = [73, 1]'),
#  Text(31.0, 54.360000000000014, 'gini = 0.0\nsamples = 69\nvalue = [69, 0]'),
#  Text(93.0, 54.360000000000014, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(186.0, 163.08000000000004, 'X[3] <= 0.063\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(155.0, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(217.0, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(279.0, 271.8, 'X[1] <= 0.155\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(248.0, 163.08000000000004, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(310.0, 163.08000000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(465.0, 380.52000000000004, 'X[1] <= 0.009\ngini = 0.413\nsamples = 79\nvalue = [56, 23]'),
#  Text(434.0, 271.8, 'X[3] <= 0.872\ngini = 0.378\nsamples = 75\nvalue = [56, 19]'),
#  Text(372.0, 163.08000000000004, 'X[1] <= -0.424\ngini = 0.198\nsamples = 36\nvalue = [32, 4]'),
#  Text(341.0, 54.360000000000014, 'gini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(403.0, 54.360000000000014, 'gini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(496.0, 163.08000000000004, 'X[2] <= 1.477\ngini = 0.473\nsamples = 39\nvalue = [24, 15]'),
#  Text(465.0, 54.360000000000014, 'gini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(527.0, 54.360000000000014, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(496.0, 271.8, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, matthews_corrcoef
from sklearn.ensemble import RandomForestClassifier

def evaluate_RandomForest(X, y,
                    metric: str='accuracy',
                    seed: int=123,
                    printout: bool=False):
    """
    Fits a decision tree with the training set, and evaluates it with 
    the test set, using Accuracy, F1, Recall or MCC metrics.

    Params
      X: A Pandas DataFrame with all the values to be used to fit the logit
      y: The dependent variable.
      metric: The metric to be returned
      printout: True/False indicating whether you want to print results

    """
    # Split the data 
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, random_state= 123, )

    # Train Model
    rf_clf = RandomForestClassifier().fit(X_train, y_train)
    y_hat = rf_clf.predict(X_test)

    # Metrics
    accuracy = accuracy_score(y_test, y_hat)
    F1 = f1_score(y_test, y_hat)
    recall = recall_score(y_test, y_hat)
    MCC = matthews_corrcoef(y_test, y_hat)
    roc_auc = roc_auc_score(y_test, y_hat)
    Gini = 2*roc_auc-1
    
    if printout is True:
        print('Accuracy:', accuracy)
        print('F1:', F1)
        print('Recall:', recall)
        print('roc_auc:', roc_auc)
        print('Gini:', Gini)
    
    return eval(metric)

# %%
corporate_accuracy_rf = evaluate_RandomForest(Xc, yc, printout=True)
corporate_accuracy_rf
# Out:
# Accuracy: 0.825
# F1: 0.0
# Recall: 0.0
# roc_auc: 0.5
# Gini: 0.0
# 0.825

# %%
X= Xc
y= yc
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 123, )

# Train Model
rf_clf = RandomForestClassifier(criterion='gini', max_depth=4, random_state=1).fit(X_train, y_train)
y_hat = dt_clf.predict(X_test)

# %%
estimator = model.estimators_[5]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = X.feature_names,
                class_names = y.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-2e8a87297acc> in <module>
#       1 from sklearn.tree import export_graphviz
#       2 # Export as dot file
# ----> 3 export_graphviz(estimator, out_file='tree.dot',
#       4                 feature_names = X.feature_names,
#       5                 class_names = y.target_names,
#
# NameError: name 'estimator' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
fig, ax = plt.subplots(figsize=(10, 10))
tree.plot_tree(rf_clf, fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-96e2582b4173> in <module>
#       3 from sklearn import tree
#       4 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 5 tree.plot_tree(rf_clf, fontsize=10)
#       6 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     193         fontsize=fontsize,
#     194     )
# --> 195     return exporter.export(decision_tree, ax=ax)
#     196
#     197
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_export.py in export(self, decision_tree, ax)
#     654         ax.clear()
#     655         ax.set_axis_off()
# --> 656         my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     657         draw_tree = buchheim(my_tree)
#     658
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'tree_'

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(Xc_train,yc_train)

#Predict the response for test dataset
yc_pred = clf.predict(Xc_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-155-25f04ae89420> in <module>
#       3
#       4 # Train Decision Tree Classifer
# ----> 5 clf = clf.fit(Xc_train,yc_train)
#       6
#       7 #Predict the response for test dataset
#
# NameError: name 'Xc_train' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=4, n_informative=2, n_redundant=0, random_state=0, shuffle=False)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X, y)
#RandomForestClassifier(...)
#print(clf.predict([[0, 0, 0, 0]]))
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#RandomForestClassifier(...)
print(clf.predict([[0, 0, 0, 0]]))
# Out:
# [1]

# %% [markdown]
# ## 8) Individual segment analysis/transformations/modelling

# %% [markdown]
# ### 8.1) Individual: Preliminary EDA

# %%
# Individual EDA and Action Plan

print("\nshape: ", data_individual.shape)
data_individual.head(3)
data_individual.info()
print("\nNulls; \n", data_individual.isnull().sum())
print("\nTarget distribution; \n", data_individual["BUCKET_BINNED"].value_counts())
print("\n\nActions:  \n-Impute missing values \n-Remove outliers \n-Scale data \n-Perform final eda before modelling \n-Train Model \n-Get Accuracy metric as baseline")

# %% [markdown]
# ### 8.2) Individual: Impute MAR values using most frequent value
# ##### (attempted to implement KNN imputation but could not make it work)

# %%
# identify missing values

data_individual.isnull().sum()

# %%
#  Impute by calling function to impute most occured category
# (impute_nan_most_frequent_category function can be found on 7.2)

impute_nan_most_frequent_category(data_individual, "PROFESSION")
impute_nan_most_frequent_category(data_individual, "CAR_TYPE")   

# Drop actual columns
data_individual.drop(["PROFESSION","CAR_TYPE"], axis=1, inplace=True)

data_individual.head(1) # confirm imputation
data_individual.isnull().sum() # confirm imputation

# %% [markdown]
# ### 8.3) Individual: Outlier detection/removal and Scaling

# %%
data_i_numerical = list(data_individual.select_dtypes(include=['number'])) 
data_i_numerical = [e for e in data_i_numerical if e not in ("ACCOUNT_NUMBER", "BUCKET_BINNED")]

data_i_categorical = list(data_individual.select_dtypes(exclude=['number']))

print("Numerical:", data_i_numerical)
print("Categorical:", data_i_categorical)

# %%
# detect and remove outliers in numerical features

Q1 = data_individual[data_c_numerical].quantile(0.25)
Q3 = data_individual[data_c_numerical].quantile(0.75)

IQR = Q3 - Q1

data_individual = data_individual[~((data_individual[data_i_numerical] < (Q1 - 1.5 * IQR)) |(data_individual[data_i_numerical] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Scale numerical features

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() # scaler

data_individual[data_i_numerical] = scaler.fit_transform(data_individual[data_i_numerical]) # Scale

data_individual.head(3) # confirm scaling

# %% [markdown]
# ### 8.4) Individual: dummy encode  categoricals for logistic regression

# %%
# data_corporate shape after outlier removal
data_individual.shape

# %%
# Dummy encode categorical columns for KNN imputation and logistic regression

di_cat_variables = data_individual[data_i_categorical]  # set categorical columns to be encoded

di_cat_dummies = pd.get_dummies(di_cat_variables) # dummy encode categorical columns
di_cat_dummies = di_cat_dummies.astype("Int64")

di_cat_dummies.head(3)  # confirm encoding

# %%
# Drop dummy encoded original column and concat new dummy columns

data_individual = pd.concat([ data_individual, di_cat_dummies], axis=1) # Concat the two dataframes together
data_individual.drop(['PROGRAM_NAME', 'SEX', 'PROFESSION_Imputed', 'CAR_TYPE_Imputed'],  axis=1, inplace=True)

data_individual.head(3)  # confirm drop/concat

# %% [markdown]
# ### 8.5) Individual: EDA

# %%
# run final EDA before trainning model

data_individual.shape
data_individual.head()
data_individual.info()
data_individual.describe()

# %% [markdown]
# ### 8.6 ) Individual:  Logit regression and Baseline metrics

# %%
# set Xi and yi for trainning the model

Xi = data_individual
yi = data_individual["BUCKET_BINNED"]
Xi.drop(["ACCOUNT_NUMBER", "BUCKET_BINNED"], axis=1, inplace=True)

# %%
# call evaluate_LogReg function to split/train/evaluate logistic regression model with set X,y
individual_accuracy = evaluate_LogReg(Xi, yi,)

# display evaluation metric
individual_accuracy

# %% [markdown]
# ## 9)  * Assignment Conclusion *

# %%
# Print final baselines

print("Accuracy Baseline for corporate segment: ", corporate_accuracy)
print("Accuracy Baseline for individual segment: ", individual_accuracy)

print("\nPROJECT COMPLETED!")
